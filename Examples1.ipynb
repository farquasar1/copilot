# %%
# create a sorting algorithm that sorts a list of numbers
# using the bubble sort algorithm
def sort(list):
    for i in range(len(list)):
        for j in range(len(list)-1):
            if list[j] > list[j+1]:
                list[j], list[j+1] = list[j+1], list[j]
    return list

# %%
#"Write a Python function to calculate the Fibonacci series, but comment each line of code as if Shakespeare himself is explaining it 

def calculate_fibonacci(n):
    """
    A function to calculate the Fibonacci series,
    where each number is the sum of the two preceding ones,
    but let us explain it in a Shakespearean manner.
    """

    # Verily, we start with the first two numbers of the series,
    # which are 0 and 1, as decreed by the gods of mathematics.
    fib_list = [0, 1]

    # Forsooth, we iterate from 2 to n, for n is the number of terms desired.
    for i in range(2, n):

        # Hark! We add the two preceding numbers in the series,
        # and append the sum to the list of Fibonacci numbers.
        fib_num = fib_list[i-1] + fib_list[i-2]
        fib_list.append(fib_num)

    # Alas! We return the list of Fibonacci numbers.
    return fib_list

# %%
#Create a function that generates random dinner recipes. 
# But here's the twist: each ingredient must be something you can find in a typical tech startup's office kitchen.

# %%
import random

def generate_random_dinner_recipe():
    """
    A function to generate random dinner recipes using ingredients
    commonly found in a typical tech startup's office kitchen.
    """

    # List of ingredients commonly found in a tech startup's office kitchen
    ingredients = [
        "avocado", "quinoa", "kale", "chickpeas", "tofu",
        "sweet potatoes", "almond butter", "sriracha", "coconut milk",
        "edamame", "hummus", "chia seeds", "nutritional yeast",
        "turmeric", "matcha", "seaweed", "miso paste", "tempeh"
    ]

    # Randomly select ingredients for the recipe
    recipe_ingredients = random.sample(ingredients, k=5)

    # Create the recipe title
    recipe_title = "Tech Startup Special: " + " ".join(recipe_ingredients)

    # Return the recipe title
    return recipe_title

generate_random_dinner_recipe()

# %%
# take two lists of ingredients one for siders and other for mains and make a recipe combining them
def generate_random_dinner_recipe_2(sides, mains):
    """
    A function to generate random dinner recipes by combining ingredients
    from two lists: one for sides and the other for mains.
    """

    # Randomly select one side and one main from the respective ingredient lists
    side = random.choice(sides)
    main = random.choice(mains)

    # Create the recipe title
    recipe_title = f"{side} with {main}"

    # Return the recipe title
    return recipe_title

# %%
sides = [
    "Truffle-infused mashed potatoes",
    "Roasted Brussels sprouts with balsamic glaze",
    "Kale and quinoa salad with lemon vinaigrette",
    "Sweet potato fries with chipotle aioli",
    "Caprese skewers with basil pesto"
]

mains = [
    "Grilled filet mignon with red wine reduction",
    "Pan-seared salmon with dill cream sauce",
    "Stuffed bell peppers with quinoa and black beans",
    "Eggplant Parmesan with marinara and mozzarella",
    "Teriyaki tofu stir-fry with mixed vegetables"
]

recipe = generate_random_dinner_recipe_2(sides, mains)
print(recipe)
# Out:
# Sweet potato fries with chipotle aioli with Pan-seared salmon with dill cream sauce

# %%
# create me a code to determine all the sibling of family class

class Person:
    def __init__(self, name):
        self.name = name
        self.siblings = []

    def add_sibling(self, sibling):
        self.siblings.append(sibling)

class Family:
    def __init__(self):
        self.members = []

    def add_member(self, member):
        self.members.append(member)

    def get_siblings(self, person):
        siblings = []
        for member in self.members:
            if member != person and person in member.siblings:
                siblings.append(member)
        return siblings
# Create some Person instances
person1 = Person("John")
person2 = Person("Jane")
person3 = Person("Mike")
person4 = Person("Emily")

# Create a Family instance
family = Family()

# Add the Person instances to the Family
family.add_member(person1)
family.add_member(person2)
family.add_member(person3)
family.add_member(person4)

# Add siblings for each person
person1.add_sibling(person2)
person1.add_sibling(person3)
person2.add_sibling(person1)
person2.add_sibling(person4)
person3.add_sibling(person1)
person4.add_sibling(person2)

# Get the siblings of a person
person = person4
siblings = family.get_siblings(person)
print(f"Siblings of {person.name}:")
for sibling in siblings:
    print(sibling.name)

# %%
# You're writing code for managing a greenhouse on Mars (à la 'The Martian').
#  Use Python to develop an algorithm that optimizes water usage for growing potatoes, 
# considering Martian environmental conditions."

# %%
def optimize_water_usage():
    # Step 1: Define the optimal moisture level
    optimal_moisture_level = 0.6

    while True:
        # Step 2: Monitor soil moisture
        soil_moisture = get_soil_moisture()

        # Step 3: Set a watering threshold
        watering_threshold = optimal_moisture_level * 0.9

        if soil_moisture < watering_threshold:
            # Step 4: Water the plants
            water_plants()

        # Step 5: Consider environmental factors
        adjust_watering_schedule()

        # Step 7: Continuously monitor and adjust
        monitor_plant_growth()

def get_soil_moisture():
    # Code to measure soil moisture using sensors
    pass

def water_plants():
    # Code to water the potato plants
    pass

def adjust_watering_schedule():
    # Code to adjust the watering schedule based on environmental factors
    pass

def monitor_plant_growth():
    # Code to monitor plant growth and make necessary adjustments
    pass

# Start the optimization process
optimize_water_usage()

# %%
#Craft a function that handles errors, but each error message must be a haiku. For example: 'Server not found / In the mist of code sea / Try again, you must.'"

# %%
def handle_errors():
    try:
        # Code that may raise an error
        # ...

    except ValueError:
        # Haiku error message for ValueError
        print("Invalid input")
        print("Numbers dance in chaos")
        print("Find harmony, friend")

    except FileNotFoundError:
        # Haiku error message for FileNotFoundError
        print("File not found, lost")
        print("In the depths of the system")
        print("Seek and you shall find")

    except ZeroDivisionError:
        # Haiku error message for ZeroDivisionError
        print("Dividing by zero")
        print("Breaks the laws of nature's math")
        print("Balance is the key")

    except Exception:
        # Haiku error message for other exceptions
        print("Error in the code")
        print("Bugs crawl through the lines of text")
        print("Debug and conquer")

# Call the handle_errors function
handle_errors()
